# %%
import numpy as np
import matplotlib as mpl
#mpl.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-deep')
plt.rcParams['axes.facecolor'] = 'white'

from sklearn import manifold
from sklearn.decomposition import PCA

# %%
dist_matrix = np.loadtxt('../../data/bn_distances/distances_dowker_minpurge.csv', 
                         delimiter = ',')

# %%
plt.matshow(dist_matrix)

# %%
#For loop to compute all MDS

base_preprocs = ['original','min1', 'minpurge', 'purge']

nice_titles = {'ripsmax': 'Rips (max)',
               'ripsmin': 'Rips (min)',
               'dowker': 'Dowker',
               'dowkershort': 'Dowker (shortest-path)',
               'walklen': 'Walk-length', 
               'original': 'No preprocessing',
               'min1': 'Min, 1',
               'minpurge': 'Min, purge',
               'purge': 'Purge',
               'originalshort': 'No preprocessing',
               'min1short': 'Min, 1',
               'minpurgeshort': 'Min, purge',
               'purgeshort': 'Purge',}

for method in ['ripsmax', 'ripsmin', 'dowker', 'dowkershort', 'walklen']:
# for method in ['dowker', 'dowkershort']:
    method_title = method
    preprocs = base_preprocs.copy()
    if method == 'dowkershort':
        preprocs = [p+'short' for p in preprocs]
        method = 'dowker'

    for prep in preprocs:
        dist_matrix = np.loadtxt('../../data/bn_distances/distances_'+method+'_'+prep+'.csv', 
                         delimiter = ',')

        dist_matrix[dist_matrix==np.inf] = np.max(dist_matrix[np.isfinite(dist_matrix)]) * 1.5

        mds = manifold.MDS(
            n_components=2,
            max_iter=500,
            eps=1e-9,
            #random_state=seed,
            dissimilarity="precomputed",
            normalized_stress='auto'
        )
        pos = mds.fit(dist_matrix).embedding_

        markers = ['o','d','X','v','s']

        plt.figure(figsize=(6, 6))
        # Plot for each class
        for h in range(5):
            plt.scatter(pos[20*h:20*(h+1), 0], pos[20*h:20*(h+1), 1],
                        s=50, marker=markers[h], label=str(h))
        plt.grid(alpha=0.5)
        plt.legend()
        
        plt.title(nice_titles[prep] + '  $\\rightarrow$  ' + nice_titles[method_title])
        # plt.show()
        plt.savefig('../figures/MDS_'+method+'_'+prep+'.png', bbox_inches='tight', dpi=500);
        plt.close()
# Out:
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:744: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9. To suppress this warning, provide some value of `n_init`.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:754: FutureWarning: The default value of `init` will change from 'random' to 'classical_mds' in 1.10. To suppress this warning, provide some value of `init`.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:771: FutureWarning: The `dissimilarity` parameter is deprecated and will be removed in 1.10. Use `metric` instead.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:744: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9. To suppress this warning, provide some value of `n_init`.
#   warnings.warn(
# ...

# %%
mds = manifold.MDS(
    n_components=2,
    max_iter=500,
    eps=1e-9,
    #random_state=seed,
    dissimilarity="precomputed",
    normalized_stress='auto'
)
pos = mds.fit(dist_matrix).embedding_

#clf = PCA(n_components=2)
#pos = clf.fit_transform(pos)
# Out:
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:744: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9. To suppress this warning, provide some value of `n_init`.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:754: FutureWarning: The default value of `init` will change from 'random' to 'classical_mds' in 1.10. To suppress this warning, provide some value of `init`.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:771: FutureWarning: The `dissimilarity` parameter is deprecated and will be removed in 1.10. Use `metric` instead.
#   warnings.warn(

# %%
markers = ['o','d','X','v','s']

plt.figure(figsize=(6, 6))
for h in range(5):
    plt.scatter(pos[20*h:20*(h+1), 0], pos[20*h:20*(h+1), 1],
                #color="turquoise", 
                s=50, marker=markers[h], label=str(h))
plt.grid(alpha=0.5)
plt.legend()

plt.title('No preprocessing  $\\rightarrow$  Dowker')
plt.savefig('../figures/MDS_dowker_original.png', bbox_inches='tight', dpi=500);

# %% [markdown]
# ## Figuring out walk-length purge outliers
#
# From the reviewer comment

# %%
method = 'walklen'
prep = 'purge'

dist_matrix = np.loadtxt('../../data/bn_distances/distances_'+method+'_'+prep+'.csv', 
                         delimiter = ',')

dist_matrix[dist_matrix==np.inf] = np.max(dist_matrix[np.isfinite(dist_matrix)]) * 1.5

mds = manifold.MDS(
    n_components=2,
    max_iter=500,
    eps=1e-9,
    dissimilarity="precomputed",
    normalized_stress='auto'
)
pos = mds.fit(dist_matrix).embedding_

markers = ['o','d','X','v','s']

plt.figure(figsize=(6, 6))
for h in range(5):
    plt.scatter(pos[20*h:20*(h+1), 0], pos[20*h:20*(h+1), 1],
                s=50, marker=markers[h], label=str(h))
plt.grid(alpha=0.5)
plt.legend()

plt.title('Purge  $\\rightarrow$  Walk-length')
plt.savefig('../figures/MDS_walklen_purge.png', bbox_inches='tight', dpi=500)
plt.show()
plt.close()
# Out:
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:744: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9. To suppress this warning, provide some value of `n_init`.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:754: FutureWarning: The default value of `init` will change from 'random' to 'classical_mds' in 1.10. To suppress this warning, provide some value of `init`.
#   warnings.warn(
# /opt/anaconda3/envs/directed-graph/lib/python3.12/site-packages/sklearn/manifold/_mds.py:771: FutureWarning: The `dissimilarity` parameter is deprecated and will be removed in 1.10. Use `metric` instead.
#   warnings.warn(

# %%
# Annotated version to identify outliers
plt.figure(figsize=(9, 9))
for h in range(5):
    plt.scatter(pos[20*h:20*(h+1), 0], pos[20*h:20*(h+1), 1],
                s=50, marker=markers[h], label=str(h))
    for i in range(20):
        plt.annotate(f'{h}-{i}', (pos[20*h+i, 0], pos[20*h+i, 1]),
                     fontsize=6, textcoords='offset points', xytext=(4, 4))
plt.grid(alpha=0.5)
plt.legend()
plt.title('Purge  $\\rightarrow$  Walk-length (annotated: class-index)')
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

# Suspected outlier networks from class 2: indices 0 and 2
mat_files = [
    '../../simHippo/allDissim/t_dissim_2_01.mat',
    '../../simHippo/allDissim/t_dissim_2_03.mat',
]

for fpath in mat_files:
    m = scipy.io.loadmat(fpath)
    print(f'\nFile: {fpath}')
    print('Keys:', [k for k in m.keys() if not k.startswith('__')])

    # In these files, the dissimilarity matrix is usually under key "dissim"
    A = m['dissim'] if 'dissim' in m else next(v for k, v in m.items() if not k.startswith('__') and isinstance(v, np.ndarray))
    A = np.asarray(A)

    print('shape =', A.shape)
    print('min/max =', np.nanmin(A), np.nanmax(A))
    print('num inf =', np.isinf(A).sum(), ' num nan =', np.isnan(A).sum())

    plt.figure(figsize=(4, 4))
    plt.imshow(A, cmap='viridis', aspect='auto')
    plt.colorbar(shrink=0.8)
    plt.title(fpath.split('/')[-1])
    plt.tight_layout()
    plt.show()
# Out:
# File: ../../simHippo/allDissim/t_dissim_2_01.mat
# Keys: ['dissim']
# shape = (189, 189)
# min/max = 0.5217391304347826 1.0
# num inf = 0  num nan = 0
# File: ../../simHippo/allDissim/t_dissim_2_03.mat
# Keys: ['dissim']
# shape = (177, 177)
# min/max = 0.4 1.0
# num inf = 0  num nan = 0

# %%
import os
import sys
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

# Make sure local package imports resolve from this notebook location
sys.path.append('../..')

from directed_persistence.walklength import walklength_filtration
from directed_persistence.ph_tools import persistence_dgms, plot_dgms


def preprocess_purge(mat):
    """
    Purge preprocessing used for walklen_purge:
    - keep weights < 1 unchanged
    - set weights equal to 1 to inf (remove those edges)
    - keep diagonal at 0
    """
    out = np.array(mat, dtype=float, copy=True)
    out[np.isclose(out, 1.0)] = np.inf
    np.fill_diagonal(out, 0.0)
    return out


targets = [
    ('t_dissim_2_01.mat', '2-0 (global index 40)'),
    ('t_dissim_2_03.mat', '2-2 (global index 42)'),
]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, (fname, label) in zip(axes, targets):
    fpath = os.path.join('../../simHippo/allDissim', fname)
    raw = scipy.io.loadmat(fpath)['dissim']
    A_purge = preprocess_purge(raw)

    filt = walklength_filtration(A_purge, max_dim=1)
    dgms = persistence_dgms(filt, max_dim=1)

    # Plot persistence diagram
    plot_dgms(dgms, figtitle=label, ax=ax, alpha=0.5)

    # Quick numeric summary for outlier debugging
    dims, births, deaths = dgms
    is_h1 = dims == 1
    h1_births = births[is_h1]
    h1_deaths = deaths[is_h1]
    h1_pers = h1_deaths - h1_births

    finite_h1 = h1_pers[np.isfinite(h1_pers)]
    print(f'\n{fname} ({label})')
    print('H1 count:', len(h1_pers), '| finite H1 count:', len(finite_h1))
    if len(finite_h1) > 0:
        print('Top 5 finite H1 persistences:', np.sort(finite_h1)[-5:][::-1])
    print('Infinite H1 count:', np.sum(np.isinf(h1_deaths)))

plt.tight_layout()
plt.show()
# Out:
# t_dissim_2_01.mat (2-0 (global index 40))
# H1 count: 2465 | finite H1 count: 2465
# Top 5 finite H1 persistences: [2.87292424 0.97166793 0.97088898 0.95925324 0.94637376]
# Infinite H1 count: 0
#
# t_dissim_2_03.mat (2-2 (global index 42))
# H1 count: 2281 | finite H1 count: 2281
# Top 5 finite H1 persistences: [2.85541667 0.96876344 0.96145449 0.96064117 0.96056698]
# Infinite H1 count: 0

# %%
import os
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

# Reuse if already defined; otherwise define locally
try:
    preprocess_purge
except NameError:
    def preprocess_purge(mat):
        out = np.array(mat, dtype=float, copy=True)
        out[np.isclose(out, 1.0)] = np.inf
        np.fill_diagonal(out, 0.0)
        return out

# Nearest neighbors to compare: 1-1 and 1-13
# Mapping to files under numHoles=1 and trial index + 1:
# 1-1  -> t_dissim_1_02.mat
# 1-13 -> t_dissim_1_14.mat
nn_targets = [
    ('t_dissim_1_02.mat', '1-1 (global index 21)'),
    ('t_dissim_1_14.mat', '1-13 (global index 33)'),
]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, (fname, label) in zip(axes, nn_targets):
    fpath = os.path.join('../../simHippo/allDissim', fname)
    raw = scipy.io.loadmat(fpath)['dissim']
    A_purge = preprocess_purge(raw)

    filt = walklength_filtration(A_purge, max_dim=1)
    dgms = persistence_dgms(filt, max_dim=1)
    plot_dgms(dgms, figtitle=label, ax=ax, alpha=0.5)

    # Quick H1 summary
    dims, births, deaths = dgms
    is_h1 = dims == 1
    h1_births = births[is_h1]
    h1_deaths = deaths[is_h1]
    h1_pers = h1_deaths - h1_births
    finite_h1 = h1_pers[np.isfinite(h1_pers)]

    print(f'\n{fname} ({label})')
    print('H1 count:', len(h1_pers), '| finite H1 count:', len(finite_h1))
    if len(finite_h1) > 0:
        print('Top 5 finite H1 persistences:', np.sort(finite_h1)[-5:][::-1])
    print('Infinite H1 count:', np.sum(np.isinf(h1_deaths)))

plt.tight_layout()
plt.show()
# Out:
# t_dissim_1_02.mat (1-1 (global index 21))
# H1 count: 2253 | finite H1 count: 2253
# Top 5 finite H1 persistences: [2.86491341 0.99929205 0.97422275 0.95830051 0.944988  ]
# Infinite H1 count: 0
#
# t_dissim_1_14.mat (1-13 (global index 33))
# H1 count: 2268 | finite H1 count: 2268
# Top 5 finite H1 persistences: [2.90314428 0.97035972 0.96922916 0.9506036  0.93860851]
# Infinite H1 count: 0

# %%
import os
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

# Reuse if already defined; otherwise define locally
try:
    preprocess_purge
except NameError:
    def preprocess_purge(mat):
        out = np.array(mat, dtype=float, copy=True)
        out[np.isclose(out, 1.0)] = np.inf
        np.fill_diagonal(out, 0.0)
        return out


def class_index_to_fname(class_label, idx_within_class):
    # Example: class 2, idx 10 -> t_dissim_2_11.mat
    return f"t_dissim_{class_label}_{idx_within_class+1:02d}.mat"


def class_index_to_global(class_label, idx_within_class):
    return 20 * class_label + idx_within_class


def plot_pd_group(points, title_prefix):
    n = len(points)
    fig, axes = plt.subplots(1, n, figsize=(5 * n, 4.5))
    if n == 1:
        axes = [axes]

    for ax, (c, i) in zip(axes, points):
        fname = class_index_to_fname(c, i)
        glb = class_index_to_global(c, i)
        label = f"{c}-{i} (global index {glb})"

        fpath = os.path.join('../../simHippo/allDissim', fname)
        raw = scipy.io.loadmat(fpath)['dissim']
        A_purge = preprocess_purge(raw)

        filt = walklength_filtration(A_purge, max_dim=1)
        dgms = persistence_dgms(filt, max_dim=1)
        plot_dgms(dgms, figtitle=label, ax=ax, alpha=0.5)

        # Quick H1 summary
        dims, births, deaths = dgms
        is_h1 = dims == 1
        h1_pers = deaths[is_h1] - births[is_h1]
        finite_h1 = h1_pers[np.isfinite(h1_pers)]

        print(f"\n{title_prefix}: {fname} ({label})")
        print('H1 count:', len(h1_pers), '| finite H1 count:', len(finite_h1))
        if len(finite_h1) > 0:
            print('Top 5 finite H1 persistences:', np.sort(finite_h1)[-5:][::-1])
        print('Infinite H1 count:', np.sum(np.isinf(deaths[is_h1])))

    plt.tight_layout()
    plt.show()


# 1) Far-away examples in class 2
plot_pd_group([(2, 10), (2, 12)], title_prefix='Far class-2 examples')

# 2) Class-3 examples near class-2 cluster
plot_pd_group([(3, 10), (3, 0), (3, 12)], title_prefix='Class-3 near class-2 cluster')
# Out:
# Far class-2 examples: t_dissim_2_11.mat (2-10 (global index 50))
# H1 count: 2715 | finite H1 count: 2715
# Top 5 finite H1 persistences: [2.7228714  2.6858423  0.99201226 0.97298931 0.9709978 ]
# Infinite H1 count: 0
#
# Far class-2 examples: t_dissim_2_13.mat (2-12 (global index 52))
# H1 count: 1729 | finite H1 count: 1729
# Top 5 finite H1 persistences: [2.79106082 2.71029554 0.99687607 0.96450189 0.96239658]
# Infinite H1 count: 0
# Class-3 near class-2 cluster: t_dissim_3_11.mat (3-10 (global index 70))
# H1 count: 1902 | finite H1 count: 1902
# Top 5 finite H1 persistences: [2.80035754 2.76448099 0.96233936 0.95474548 0.95307512]
# Infinite H1 count: 0
#
# Class-3 near class-2 cluster: t_dissim_3_01.mat (3-0 (global index 60))
# H1 count: 1770 | finite H1 count: 1770
# Top 5 finite H1 persistences: [2.88989952 2.74694783 0.95825108 0.95127566 0.94693694]
# Infinite H1 count: 0
#
# Class-3 near class-2 cluster: t_dissim_3_13.mat (3-12 (global index 72))
# ...

# %%
# Compare 3-19 and 4-8: focus on high-persistence H1 features
# 3-19 -> t_dissim_3_20.mat  (class 3, index 19)
# 4-8  -> t_dissim_4_09.mat  (class 4, index 8)

targets = [(3, 19), (4, 8)]
persistence_threshold = 0.0  # show ALL H1 points; raise to filter low-persistence noise

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, (c, i) in zip(axes, targets):
    fname = class_index_to_fname(c, i)
    glb = class_index_to_global(c, i)
    label = f"{c}-{i} (global index {glb})"

    fpath = os.path.join('../../simHippo/allDissim', fname)
    raw = scipy.io.loadmat(fpath)['dissim']
    A_purge = preprocess_purge(raw)

    filt = walklength_filtration(A_purge, max_dim=1)
    dgms = persistence_dgms(filt, max_dim=1)
    plot_dgms(dgms, figtitle=label, ax=ax, alpha=0.5)

    dims, births, deaths = dgms
    is_h1 = dims == 1
    h1_births = births[is_h1]
    h1_deaths = deaths[is_h1]
    h1_pers = h1_deaths - h1_births
    finite_h1 = h1_pers[np.isfinite(h1_pers)]
    inf_h1_count = int(np.sum(np.isinf(h1_deaths)))

    # Define 'high persistence' as top quartile of finite H1 persistences
    if len(finite_h1) > 0:
        threshold = np.percentile(finite_h1, 75)
        high_pers = finite_h1[finite_h1 >= threshold]
    else:
        threshold = float('nan')
        high_pers = np.array([])

    print(f'\n--- {fname} ({label}) ---')
    print(f'Total H1: {len(h1_pers)}  |  Finite H1: {len(finite_h1)}  |  Infinite H1: {inf_h1_count}')
    if len(finite_h1) > 0:
        print(f'All finite H1 persistences (sorted desc): {np.sort(finite_h1)[::-1][:7]}')
        # print(f'Top-quartile threshold: {threshold:.4f}  |  High-persistence count: {len(high_pers)}')
        # print(f'High-persistence values: {np.sort(high_pers)[:6]}')

plt.suptitle('Persistence diagram comparison: 3-19 vs 4-8', fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# --- t_dissim_3_20.mat (3-19 (global index 79)) ---
# Total H1: 1977  |  Finite H1: 1977  |  Infinite H1: 0
# All finite H1 persistences (sorted desc): [2.86945002 2.86834507 1.99088608 0.97639189 0.95101707 0.9509649
#  0.94820525]
#
# --- t_dissim_4_09.mat (4-8 (global index 88)) ---
# Total H1: 1684  |  Finite H1: 1684  |  Infinite H1: 0
# All finite H1 persistences (sorted desc): [2.89456598 2.86899509 1.9915859  0.93968795 0.93371758 0.92555992
#  0.92352185]

# %% [markdown]
# ## Connecting label and number of high persistence points
