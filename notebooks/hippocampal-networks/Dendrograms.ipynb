# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dist_matrix = np.loadtxt('../../simHippo/diagrams/distances_ripsmax_original.csv',
          delimiter = ',')

# %%
#dist_matrix[dist_matrix==np.inf] = 0.25

# Flatten out
X = []
for r in range(99):
    X += list(dist_matrix[r,r+1:])

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

network_labels = [str(int(i/20)*'o') for i in range(100)]

Z = linkage(X, 'single')
fig = plt.figure(figsize=(7, 11))
dn = dendrogram(Z,
               labels = network_labels,
               orientation = 'right', color_threshold = 0.0)
plt.savefig('../figures/dendrogram_ripsmax_original.png', bbox_inches='tight', dpi=400)
